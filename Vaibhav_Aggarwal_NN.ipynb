# %% [markdown]
# # Project Pipeline
#
# 1.   Dataset Reading/understading
# 2.   Dataset Creation and Visualisation
# 4.   Model Building & training

# %% [markdown]
# #1.Dataset Reading

# %% [markdown]
# Mounting GDrive.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Importing all the important libraries

# %%
# Import the pathlib library to work with file paths
import pathlib

# Import the TensorFlow library for machine learning and deep learning tasks
import tensorflow as tf

# Import the matplotlib library for data visualization
import matplotlib.pyplot as plt

# Import the numpy library for numerical computations
import numpy as np

# Import the pandas library for data manipulation and analysis
import pandas as pd

# Import the os module for interacting with the operating system
import os

# Import the PIL (Python Imaging Library) for image processing tasks
import PIL

# Import the Keras module from TensorFlow for building and training neural networks
from tensorflow import keras

# Import specific classes and functions from Keras for building models and layers
from tensorflow.keras import layers

# Import the Sequential model from Keras for building sequential models
from tensorflow.keras.models import Sequential

# Import the Adam optimizer from Keras for optimization during model training
from tensorflow.keras.optimizers import Adam

# Import specific callback functions from Keras for model training callbacks
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Import the load_img function from Keras for loading images
from tensorflow.keras.preprocessing.image import load_img

# %%
# Defining the path for train and test images

# Define the path for the training dataset

data_dir_train = pathlib.Path('/content/gdrive/MyDrive/Melanoma Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train')

# Define the path for the test dataset

data_dir_test = pathlib.Path('/content/gdrive/MyDrive/Melanoma Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
# Count the number of images in the training directory
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))

# Print the count of images in the training directory
print("Number of images in the training directory:", image_count_train)

# Count the number of images in the test directory
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))

# Print the count of images in the test directory
print("Number of images in the test directory:", image_count_test)
# Out:
# Number of images in the training directory: 2239
# Number of images in the test directory: 118

# %% [markdown]
# # 2.Dataset creation , visualisation

# %%
# Visualizing One Instance from Each Class in the Dataset

# Using image_dataset_from_directory() to create a dataset that yields batches of labeled images
# label_mode is set to 'categorical' for one-hot encoding of class labels
image_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train, batch_size=32, image_size=(180, 180), label_mode='categorical', seed=123
)

# Get the names of all the classes (skin cancer types)
class_names = image_dataset.class_names

# Dictionary to store image paths for each class
files_path_dict = {}

# Loop through each class to gather image paths
for c in class_names:
    files_path_dict[c] = list(map(lambda x: str(data_dir_train) + '/' + c + '/' + x, os.listdir(str(data_dir_train) + '/' + c)))

# Visualize an image from each class
plt.figure(figsize=(15, 15))
index = 0
for c in class_names:
    path_list = files_path_dict[c][:1]
    index += 1
    plt.subplot(3, 3, index)

    # Load and display the image
    plt.imshow(load_img(path_list[0], target_size=(180, 180)))
    plt.title(c)
    plt.axis("off")
# Out:
# Found 15739 files belonging to 9 classes.

# %%
# Define a function to count and analyze the distribution of images in each class

def class_distribution_count(directory):
    # Initialize a list to store image counts for each class
    count = []

    # Count the number of images in each class directory
    for path in pathlib.Path(directory).iterdir():
        if path.is_dir():
            count.append(len([name for name in os.listdir(path) if os.path.isfile(os.path.join(path, name))]))

    # Get the names of the classes (sub-directories)
    sub_directory = [name for name in os.listdir(directory) if os.path.isdir(os.path.join(directory, name))]

    # Create a DataFrame with class names and corresponding image counts
    df = pd.DataFrame(list(zip(sub_directory, count)), columns=['Class', 'No. of Images'])

    # Sort the DataFrame in ascending order of image counts
    df = df.sort_values(by='No. of Images', ascending=True)

    # Return the sorted DataFrame
    return df

# Call the function to get the class distribution and image count
class_distribution_df = class_distribution_count(data_dir_train)

# Display the DataFrame
class_distribution_df
# Out:
#                         Class  No. of Images
# 5        seborrheic keratosis             77
# 6              dermatofibroma             95
# 8           actinic keratosis            114
# 7             vascular lesion            139
# 2     squamous cell carcinoma            181
# 3                       nevus            357
# 4        basal cell carcinoma            376
# 0                    melanoma            438
# 1  pigmented benign keratosis            462

# %%
# Visualize the Number of Images in Each Class

# Import the seaborn library for data visualization
import seaborn as sns

# Set the size of the plot figure
plt.figure(figsize=(10, 8))

# Create a bar plot using seaborn
# x-axis: Number of Images
# y-axis: Class names
# Data source: df DataFrame
# Label: "Class"
sns.barplot(x="No. of Images", y="Class", data= class_distribution_df, label="Class")

# Add a title to the plot
plt.title("Number of Images in Each Class")

# Display the plot
plt.show()

# %% [markdown]
# # 2.1 Handling class imbalances

# %%
# Install Augmentor library
# !pip install -q Augmentor

# Define the path to the training dataset
path_to_training_dataset = "/content/gdrive/MyDrive/Melanoma Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"

# Import the Augmentor library
import Augmentor

# Loop through each class and perform data augmentation
for i in class_names:
    # Create an Augmentor pipeline for the current class
    p = Augmentor.Pipeline(path_to_training_dataset + i)

    # Apply rotation augmentation with specified parameters
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)

    # Generate and save 500 augmented samples for each class
    p.sample(500)  # Adding 500 samples per class to ensure class balance
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7D3E005BD510>: 100%|██████████| 500/500 [00:20<00:00, 24.86 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7D3D8E13B3A0>: 100%|██████████| 500/500 [00:21<00:00, 23.03 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7D3D8E19AD40>: 100%|██████████| 500/500 [00:20<00:00, 24.21 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=767x576 at 0x7D3E1E75AB30>: 100%|██████████| 500/500 [01:33<00:00,  5.34 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=1504x1129 at 0x7D3E00763460>: 100%|██████████| 500/500 [01:23<00:00,  6.00 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7D3E1FFFB820>: 100%|██████████| 500/500 [00:21<00:00, 23.20 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7D3E0FFA4430>: 100%|██████████| 500/500 [00:42<00:00, 11.63 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7D3E1EB6C100>: 100%|██████████| 500/500 [00:21<00:00, 23.74 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma Detection/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7D3DB098B370>: 100%|██████████| 500/500 [00:19<00:00, 25.52 Samples/s]

# %%
# Count the Total Number of Augmented Images Generated by Augmentor

# Count the number of image files in the 'output' subdirectories of each class
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))

# Print the total count of augmented images
print("Total number of augmented images:", image_count_train)
# Out:
# Total number of augmented images: 13500

# %% [markdown]
# # 3.Model Building & training

# %%
#Model Building

# Create a Training Dataset

# Use image_dataset_from_directory() to create a training dataset from the training directory
# Batch size: 32 images per batch
# Image size: 180x180 pixels
# Label mode: 'categorical' for one-hot encoded class labels
# Seed: 123 for random shuffling consistency
# Subset: "training" to select the training subset of the dataset
# Validation split: 20% of the data is used for validation
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train, batch_size=32, image_size=(180, 180), label_mode='categorical',
    seed=123, subset="training", validation_split=0.2
)

# Note: With label_mode set to 'categorical', the labels are represented as a float32 tensor
# of shape (batch_size, num_classes), where each label is a one-hot encoding of the class index.
# Out:
# Found 15739 files belonging to 9 classes.
# Using 12592 files for training.

# %%
# Create a Validation Dataset

# Use image_dataset_from_directory() to create a validation dataset from the training directory
# Batch size: 32 images per batch
# Image size: 180x180 pixels
# Label mode: 'categorical' for one-hot encoded class labels
# Seed: 123 for random shuffling consistency
# Subset: "validation" to select the validation subset of the dataset
# Validation split: 20% of the data is used for validation
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train, batch_size=32, image_size=(180, 180), label_mode='categorical',
    seed=123, subset="validation", validation_split=0.2
)
# Out:
# Found 15739 files belonging to 9 classes.
# Using 3147 files for validation.

# %%
# Define the appropriate number of processes that are free for working using AUTOTUNE
AUTOTUNE = tf.data.experimental.AUTOTUNE

# Cache the training dataset in memory after loading images from disk during the first epoch
# This helps improve data loading speed for subsequent epochs
train_ds = train_ds.cache()

# Shuffle the training dataset to introduce randomness during training
# and prevent the model from memorizing the order of examples
train_ds = train_ds.shuffle(1000)

# Prefetch data for training to overlap data preprocessing and model execution
# This can lead to better GPU utilization and overall training performance
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)

# Cache the validation dataset in memory
# Caching the validation data can help improve evaluation speed
val_ds = val_ds.cache()

# Prefetch data for validation
# Similar to training, prefetching can enhance validation performance
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # 3.1 CNN Model Architecture

# %%
# CNN Model Architecture

# Sequential allows you to create models layer-by-layer
model = Sequential()

# Rescaling Layer: Scale input pixel values to the [0, 1] range
model.add(tf.keras.layers.Rescaling(1./255, input_shape=(180, 180, 3)))

# First Convolutional layer
model.add(layers.Conv2D(32, kernel_size=(3, 3), activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2, 2)))

# Second Convolutional Layer
model.add(layers.Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2, 2)))

# Third Convolutional Layer
model.add(layers.Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2, 2)))

# Dropout layer with 50% Fraction of the input units to drop
model.add(layers.Dropout(0.5))

# Flatten Layer: Convert multi-dimensional input tensors into a single dimension
model.add(layers.Flatten())

# Dense Layer: Fully connected layer with 128 units and ReLU activation
model.add(layers.Dense(128, activation='relu'))

# Dropout layer with 25% Fraction of the input units to drop
model.add(layers.Dropout(0.25))

# Dense Layer with softmax activation function
# Softmax scales logits into probabilities
model.add(layers.Dense(len(class_names), activation='softmax'))

# Display model summary
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)                │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 178, 178, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 89, 89, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 87, 87, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 43, 43, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 41, 41, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 20, 20, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 20, 20, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 51200)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       6,553,728 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 9)                   │           1,161 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 6,648,137 (25.36 MB)
#  Trainable params: 6,648,137 (25.36 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Visualizing the Model Architecture

# Import the necessary function from TensorFlow Keras utilities
from tensorflow.keras.utils import plot_model

# Plot the model architecture and save it as an image file
# Set show_shapes=True to display the shapes of the input/output tensors in the plot
# Set show_layer_names=True to display the names of the layers in the plot
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### **Summary of CNN Architecture Analysis**
#
# 1. **Input Preprocessing**:
#    - **Rescaling**: Normalizes pixel values to the range [0, 1].
#    - **Input Shape**: `(180, 180, 3)` (RGB image).
#
# 2. **Convolutional and Pooling Layers**:
#    - **3 Convolutional Layers** with increasing filters:
#      - **32 → 64 → 128**.
#    - Each convolutional layer is followed by **MaxPooling2D**:
#      - Reduces spatial dimensions from `(180, 180, 3)` to `(20, 20, 128)`.
#
# 3. **Overfitting Control**:
#    - **Dropout Layers**:
#      - 50% dropout after convolutional layers.
#      - 25% dropout after the first dense layer.
#
# 4. **Dense Layers**:
#    - **Flatten Layer**: Converts 2D feature maps into a 1D vector.
#    - **First Dense Layer**: 128 neurons with **ReLU** activation.
#    - **Output Layer**: 9 neurons with **Softmax** activation for class probabilities.
#
# 5. **Strengths**:
#    - Efficient hierarchical feature extraction.
#    - Overfitting is reduced using **Dropout** and **MaxPooling**.
#    - Output shape aligns perfectly for **9-class classification**.
#
# 6. **Suggestions for Improvement**:
#    - Add **Batch Normalization** for faster convergence and training stabilization.
#    - Use **Early Stopping** to monitor validation accuracy and prevent overfitting.
#
# ---

# %%
# Compile the Model

# Compile the model with Adam optimization
# Adam is a stochastic gradient descent method with adaptive estimation of moments
# Categorical crossentropy is used as the loss function for multi-class classification
model.compile(optimizer="Adam", loss="categorical_crossentropy", metrics=["accuracy"])

# ModelCheckpoint callback is used to save the model or weights at specific intervals
# It saves the best model based on the validation accuracy
# The saved model can be loaded later to continue training from the saved state
checkpoint = ModelCheckpoint("model.keras", monitor="val_accuracy", save_best_only=True, mode="auto", verbose=1)

# EarlyStopping callback is used to stop training when a monitored metric stops improving
# It helps prevent overfitting by stopping training when validation accuracy plateaus
earlystop = EarlyStopping(monitor="val_accuracy", patience=5, mode="auto", verbose=1)

# %% [markdown]
# # 3.2 epochs is 50

# %%
# Train the Model

# Set the number of training epochs
epochs = 50

# Train the model using the training dataset and validate on the validation dataset
# Use the ModelCheckpoint and EarlyStopping callbacks defined earlier
history = model.fit(train_ds, validation_data=val_ds, epochs=epochs, callbacks=[checkpoint, earlystop])
# Out:
# Epoch 1/50
# 393/394 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2429 - loss: 1.9424
# Epoch 1: val_accuracy improved from -inf to 0.48046, saving model to model.keras
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 127s 101ms/step - accuracy: 0.2434 - loss: 1.9410 - val_accuracy: 0.4805 - val_loss: 1.3258
# Epoch 2/50
# 393/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5048 - loss: 1.3127
# Epoch 2: val_accuracy improved from 0.48046 to 0.58182, saving model to model.keras
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 17s 43ms/step - accuracy: 0.5049 - loss: 1.3123 - val_accuracy: 0.5818 - val_loss: 1.1358
# Epoch 3/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6277 - loss: 1.0021
# Epoch 3: val_accuracy improved from 0.58182 to 0.70734, saving model to model.keras
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.6278 - loss: 1.0019 - val_accuracy: 0.7073 - val_loss: 0.8111
# Epoch 4/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7130 - loss: 0.7919
# Epoch 4: val_accuracy improved from 0.70734 to 0.80172, saving model to model.keras
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 16s 42ms/step - accuracy: 0.7131 - loss: 0.7918 - val_accuracy: 0.8017 - val_loss: 0.5762
# Epoch 5/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7851 - loss: 0.5831
# Epoch 5: val_accuracy improved from 0.80172 to 0.84048, saving model to model.keras
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 18s 47ms/step - accuracy: 0.7851 - loss: 0.5832 - val_accuracy: 0.8405 - val_loss: 0.5059
# Epoch 6/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8101 - loss: 0.5265
# Epoch 6: val_accuracy did not improve from 0.84048
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 14s 31ms/step - accuracy: 0.8101 - loss: 0.5265 - val_accuracy: 0.8306 - val_loss: 0.4801
# Epoch 7/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8335 - loss: 0.4656
# Epoch 7: val_accuracy improved from 0.84048 to 0.87957, saving model to model.keras
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 18s 47ms/step - accuracy: 0.8335 - loss: 0.4656 - val_accuracy: 0.8796 - val_loss: 0.3696
# Epoch 8/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8522 - loss: 0.3964
# Epoch 8: val_accuracy improved from 0.87957 to 0.89355, saving model to model.keras
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 18s 42ms/step - accuracy: 0.8522 - loss: 0.3964 - val_accuracy: 0.8935 - val_loss: 0.3316
# Epoch 9/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8745 - loss: 0.3478
# Epoch 9: val_accuracy did not improve from 0.89355
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 16s 31ms/step - accuracy: 0.8744 - loss: 0.3478 - val_accuracy: 0.8862 - val_loss: 0.3443
# Epoch 10/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8918 - loss: 0.2964
# Epoch 10: val_accuracy did not improve from 0.89355
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.8918 - loss: 0.2964 - val_accuracy: 0.8812 - val_loss: 0.3815
# Epoch 11/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8990 - loss: 0.2748
# Epoch 11: val_accuracy improved from 0.89355 to 0.90658, saving model to model.keras
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 27s 48ms/step - accuracy: 0.8989 - loss: 0.2748 - val_accuracy: 0.9066 - val_loss: 0.2960
# Epoch 12/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9040 - loss: 0.2470
# Epoch 12: val_accuracy did not improve from 0.90658
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 14s 32ms/step - accuracy: 0.9040 - loss: 0.2471 - val_accuracy: 0.8942 - val_loss: 0.3320
# Epoch 13/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8996 - loss: 0.2648
# Epoch 13: val_accuracy did not improve from 0.90658
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.8996 - loss: 0.2648 - val_accuracy: 0.8964 - val_loss: 0.3446
# Epoch 14/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9077 - loss: 0.2521
# Epoch 14: val_accuracy did not improve from 0.90658
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.9077 - loss: 0.2521 - val_accuracy: 0.9059 - val_loss: 0.3119
# Epoch 15/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9182 - loss: 0.2229
# Epoch 15: val_accuracy improved from 0.90658 to 0.90848, saving model to model.keras
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 18s 46ms/step - accuracy: 0.9181 - loss: 0.2230 - val_accuracy: 0.9085 - val_loss: 0.3159
# Epoch 16/50
# 393/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9077 - loss: 0.2577
# Epoch 16: val_accuracy did not improve from 0.90848
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - accuracy: 0.9077 - loss: 0.2575 - val_accuracy: 0.9075 - val_loss: 0.3194
# Epoch 17/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9202 - loss: 0.2141
# Epoch 17: val_accuracy improved from 0.90848 to 0.91706, saving model to model.keras
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 27s 47ms/step - accuracy: 0.9202 - loss: 0.2141 - val_accuracy: 0.9171 - val_loss: 0.2965
# Epoch 18/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9250 - loss: 0.2031
# Epoch 18: val_accuracy did not improve from 0.91706
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - accuracy: 0.9250 - loss: 0.2031 - val_accuracy: 0.9078 - val_loss: 0.3062
# Epoch 19/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9271 - loss: 0.1958
# Epoch 19: val_accuracy improved from 0.91706 to 0.91802, saving model to model.keras
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 22s 36ms/step - accuracy: 0.9271 - loss: 0.1958 - val_accuracy: 0.9180 - val_loss: 0.3049
# Epoch 20/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9245 - loss: 0.1999
# Epoch 20: val_accuracy did not improve from 0.91802
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - accuracy: 0.9245 - loss: 0.1999 - val_accuracy: 0.9123 - val_loss: 0.2938
# Epoch 21/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9309 - loss: 0.1755
# Epoch 21: val_accuracy did not improve from 0.91802
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.9309 - loss: 0.1755 - val_accuracy: 0.9098 - val_loss: 0.3301
# Epoch 22/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9317 - loss: 0.1788
# Epoch 22: val_accuracy improved from 0.91802 to 0.91992, saving model to model.keras
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 17s 42ms/step - accuracy: 0.9317 - loss: 0.1788 - val_accuracy: 0.9199 - val_loss: 0.3033
# Epoch 23/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9352 - loss: 0.1694
# Epoch 23: val_accuracy did not improve from 0.91992
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.9352 - loss: 0.1694 - val_accuracy: 0.9199 - val_loss: 0.3126
# Epoch 24/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9329 - loss: 0.1744
# Epoch 24: val_accuracy did not improve from 0.91992
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.9329 - loss: 0.1744 - val_accuracy: 0.9056 - val_loss: 0.3318
# Epoch 25/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9350 - loss: 0.1775
# Epoch 25: val_accuracy did not improve from 0.91992
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.9350 - loss: 0.1775 - val_accuracy: 0.9133 - val_loss: 0.3218
# Epoch 26/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9342 - loss: 0.1758
# Epoch 26: val_accuracy did not improve from 0.91992
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - accuracy: 0.9342 - loss: 0.1758 - val_accuracy: 0.9024 - val_loss: 0.3742
# Epoch 27/50
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9397 - loss: 0.1536
# Epoch 27: val_accuracy did not improve from 0.91992
# 394/394 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.9397 - loss: 0.1536 - val_accuracy: 0.9091 - val_loss: 0.3546
# Epoch 27: early stopping

# %% [markdown]
# # 3.3 Plotting Training curves

# %%
# Plot the Training Curves

# Get the range of epochs where training was stopped by EarlyStopping
epochs_range = range(earlystop.stopped_epoch + 1)

# Create a figure with two subplots for accuracy and loss
plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)

# Plot Model Accuracy
plt.plot(epochs_range, history.history['accuracy'], label='Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(loc='upper left')

# Plot Model Loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, history.history['loss'], label='Training Loss')
plt.plot(epochs_range, history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc='upper left')

# Display the plots
plt.show()

# %% [markdown]
# ### **Model Training and Validation Analysis**
#
# #### **1. Model Accuracy**
# - The training accuracy (blue line) and validation accuracy (orange line) both increase steadily over the epochs.
# - **Key Observations**:
#   - Initially, there is a significant gap between training and validation accuracy, indicating the model is learning general features.
#   - Around **epoch 10**, both accuracies converge, and the gap reduces.
#   - By the end of training (epoch 25), the validation accuracy stabilizes slightly below the training accuracy at ~92%.
# - **Conclusion**: The model achieves high accuracy, with minimal overfitting. The accuracy curve indicates successful learning and generalization.
#
# ---
#
# #### **2. Model Loss**
# - The training loss (blue line) and validation loss (orange line) decrease rapidly during the early epochs.
# - **Key Observations**:
#   - Both training and validation loss drop sharply until **epoch 10**, showing effective learning.
#   - After epoch 10, the training loss continues to decrease gradually, while the validation loss stabilizes and fluctuates slightly.
#   - A slight upward trend in validation loss around epoch 20 indicates potential early signs of **overfitting**.
# - **Conclusion**: The model shows good convergence, but further training might increase overfitting.
#
# ---
#
# ### **Overall Findings**
# - The model demonstrates effective learning, with both accuracy and loss curves indicating a good fit.
# - Slight overfitting may be occurring in later epochs, as seen by the divergence between training and validation loss.
# - Recommendations:
#   - Implement **Early Stopping** to stop training when validation loss stops improving.
#   - Experiment with **Dropout rates** or **L2 regularization** to further reduce overfitting.
#   - Fine-tune hyperparameters, such as learning rate or batch size, to optimize results.

# %%
from glob import glob

# Construct the path to a test image
test_image_path = os.path.join(data_dir_test, class_names[1], '*')

# Get a list of all test images for the selected class
test_images = glob(test_image_path)

# Load the last test image in the list
test_image = load_img(test_images[-1], target_size=(180, 180, 3))

# Display the test image
plt.imshow(test_image)
plt.grid(False)

# Expand dimensions to match the input shape of the model
img = np.expand_dims(test_image, axis=0)

# Make predictions using the trained model
pred = model.predict(img)

# Get the index of the predicted class with the highest probability
pred = np.argmax(pred)

# Get the predicted class name
pred_class = class_names[pred]

# Print the actual and predicted class names
print("Actual Class: " + class_names[1])
print("Predicted Class: " + pred_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Actual Class: basal cell carcinoma
# Predicted Class: pigmented benign keratosis
